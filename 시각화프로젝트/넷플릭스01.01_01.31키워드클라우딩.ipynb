# %%
# !pip install nltk
# Out:
# ...
#      ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#      ------------------------------- -------- 1.2/1.5 MB 25.3 MB/s eta 0:00:01
#      ---------------------------------------- 1.5/1.5 MB 19.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/267.7 kB ? eta -:--:--
#      ---------------------------------------- 267.7/267.7 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 0.0/298.0 kB ? eta -:--:--
#      -------------------------------------- 298.0/298.0 kB 9.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/78.5 kB ? eta -:--:--
#      ---------------------------------------- 78.5/78.5 kB ? eta 0:00:00
# ...

# %%
from wordcloud import WordCloud
from PIL import Image
from konlpy.tag import Okt
okt = Okt()
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


import os
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\TECH2_25\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\TECH2_25\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
print(stopwords.words('korean'))
# Out:
# ['아', '휴', '아이구', '아이쿠', '아이고', '어', '나', '우리', '저희', '따라', '의해 ', '을 ', '를 ', '에 ', '의 ', '가 ', '으로 ', '로 ', '에게 ', '뿐이다 ', '의거하여 ', '근거하여 ', '입각하여 ', '기준으로 ', '예하면 ', '예를 ', '들면 ', '예를 들자면 ', '저 ', '소인 ', '소생 ', '저희 ', '지말고 ', '하지마 ', '하지마라 ', '다른', '물론 ', '또한 ', '그리고 ', '비길수 ', '없다 ', '해서는 ', '안된다 ', '뿐만', '아니라', '만이 ', '아니다', '만은', '아니다 ', '막론하고 ', '관계없이 ', '그치지 ', '않다 ', '그러나', '그런데', '하지만 ', '든간에 ', '논하지 ', '않다 ', '따지지 ', '않다 ', '설사 ', '비록 ', '더라도 ', '아니면 ', '만 ', '못하다 ', '하는 ', '편이 ', '낫다 ', '불문하고 ', '향하여 ', '향해서 ', '향하다 ', '쪽으로 ', '틈타 ', '이용하여 ', '타다 ', '오르다 ', '제외하고 ', '이 ', '외에 ', '이 ', '밖에 ', '하여야 ', '비로소 ', '한다면 ', '몰라도 ', '외에도 ', '이곳 ', '여기 ', '부터 ', '기점으로 ', '따라서', '할', '생각이다', '하려고하다', '이리하여 ', '그리하여 ', '그렇게 ', '함으로써 ', '하지만 ', '일때 ', '할때 ', '앞에서 ', '중에서 ', '보는데서 ', '으로써 ', '로써 ', '까지 ', '해야한다 ', '일것이다 ', '반드시 ', '할줄알다 ', '할수있다 ', '할수있어 ', '임에 ', '틀림없다 ', '한다면', '등 ', '등등 ', '제 ', '겨우', '단지', '다만', '할뿐', '딩동 ', '댕그 ', '대해서 ', '대하여 ', '대하면 ', '훨씬 ', '얼마나 ', '얼마만큼 ', '얼마
# ...

# %%
print(os.getcwd())
# Out:
# C:\Users\TECH2_25\TIL\시각화프로젝트

# %%
nflx_kw = pd.read_csv('./nflx_wordcloud.csv', encoding='utf-8')

# %%
nflx_kw
# Out:
#       Unnamed: 0                                            제목  \
# 0              0  크레디트스위스 "테슬라만한 기업 없다 지금이 매수 기회" [강영연의 뉴욕오프닝]
# 1              1    "돈자랑, 명품자랑 좀 그만 했으면" 송지아 압도적 1위 굴욕 2위는 이다인
# 2              2               코로나19 속 두번째 설...'집콕'은 이제 국룰이 됐다
# 3              3            가입자 수 한계 부딪친 넷플릭스...돌파구는 게임 결합요금제?
# 4              4             넷플릭스 ‘지금 우리 학교는’, TV쇼 시리즈 전세계 1위.
# ...          ...                                           ...
# 2345        2345           왓챠 떠난 '왕좌의 게임' 넷플 디플 벅찬데 '더 센 놈' 온다
# 2346        2346        [디지털 혁신의 시대로] ③ 올해도 'K콘텐츠' 글로벌 열풍 이어간다
# 2347        2347              [최현주의 밥상+머리] 새해에 마주할 어떤 친구들에 대하여
# 2348        2348              [사설] 역경을 희망으로 극복하고 화해와 통합의 시대 열자
# 2349        2349   “거품 낀 세계경제, 또다른 충격 온다” vs “美 증시 20% 이상 오른다”
#
#                                                     키워드  \
# 0     크레디트스위스,테슬라,기업,매수,기회,강영연,뉴욕오프닝,기사,글로벌마켓,최대,해외,...
# 1     돈자랑,명품자랑,송지아,압도,굴욕,2위,이다,명품,가품,짝퉁,착용,논란,활동,중단,...
# ...

# %%
def okt_morpheme(text):
    return okt.pos(text)

# %%
nflx_kw['분석결과'] = nflx_kw['제목'].apply(okt_morpheme)

# %%
nflx_kw.to_csv('제목분석.csv', encoding='utf-8', index=False)

# %%
nflx_kw = pd.read_csv('./제목분석.csv')

# %%
print(nflx_kw['분석결과'])
# Out:
# 0       [('크레디트', 'Noun'), ('스위스', 'Noun'), ('"', 'Pun...
# 1       [('"', 'Punctuation'), ('돈자', 'Noun'), ('랑', '...
# 2       [('코로나', 'Noun'), ('19', 'Number'), ('속', 'Nou...
# 3       [('가입자', 'Noun'), ('수', 'Noun'), ('한계', 'Noun'...
# 4       [('넷플릭스', 'Noun'), ('‘', 'Foreign'), ('지금', 'N...
#                               ...
# 2345    [('왓챠', 'Noun'), ('떠난', 'Verb'), ("'", 'Punctu...
# 2346    [('[', 'Punctuation'), ('디지털', 'Noun'), ('혁신',...
# 2347    [('[', 'Punctuation'), ('최현주', 'Noun'), ('의', ...
# 2348    [('[', 'Punctuation'), ('사설', 'Noun'), (']', '...
# 2349    [('“', 'Foreign'), ('거품', 'Noun'), ('낀', 'Verb...
# Name: 분석결과, Length: 2350, dtype: object

# %%
# 불용어처리

sentence = ' '.join(nflx_kw['제목'])  # 모든 문자열을 공백으로 연결하여 하나의 문자열로 만듦
stop_words = set(stopwords.words('korean'))

words = word_tokenize(sentence)

filtered_words = [word for word in words if not word in stop_words]

print(filtered_words)
# Out:
# ['크레디트스위스', '``', '테슬라만한', '기업', '없다', '지금이', '매수', '기회', "''", '[', '강영연의', '뉴욕오프닝', ']', '``', '돈자랑', ',', '명품자랑', '좀', '그만', '했으면', "''", '송지아', '압도적', '1위', '굴욕', '2위는', '이다인', '코로나19', '속', '두번째', '설', '...', "'집콕", "'", '은', '이제', '국룰이', '됐다', '가입자', '수', '한계', '부딪친', '넷플릭스', '...', '돌파구는', '게임', '결합요금제', '?', '넷플릭스', '‘', '지금', '학교는', '’', ',', 'TV쇼', '시리즈', '전세계', '1위', '.', '``', '돈', '명품', '자랑', '멈췄으면', "''", '압도적', '1위', '송지아', '2위는', '견미리', '딸', "'지금", '학교는', "'", '이유미', "'오징어게임", "'", '이어', '연타석', '홈런', '외신도', '‘', '지금', '우리학교는', '’', '극찬', '“', '한국은', '좀비물', '최강자', '”', "'지금", '학교는', "'", ',', '이틀째', '글로벌', '1위', "'오겜", "'", "'지옥", "'", '열풍', '잇는다', '송지아', '이번엔', '``', '돈', '명품', '자랑', '그만했으면', "''", '또', '굴욕', '野', '‘', '유튜브', '콘텐츠', '’', '전쟁', '尹', '安의', '뉴미디어', '활용법', '[', '정치쫌', '!', ']', '송지아', '이다인', '도끼', ',', '돈자랑', ',', '명품자랑', '그만했으면', '하는', 'SNS', '스타', '1~3위', '이틀', '연속', '글로벌', '1위', '오른', "'지우학", "'", '제이콘텐트리', '주가', '요동치나', 'OTT', '인기', '속', '개인방송', '앱', 
# ...
