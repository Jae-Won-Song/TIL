# %%
# !pip install pykrx

from pykrx import stock
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from pykrx import stock

stock.get_market_ticker_list("20101025, market=KOSPI")
stock.get_market_ticker_name("005930")
# Out:
# '삼성전자'

# %%
df = stock.get_market_price_change_by_ticker(fromdate='20100101', todate='20200101',market='KOSPI')

df
# Out:
# C:\Users\TECH2_25\AppData\Roaming\Python\Python39\site-packages\pykrx\stock\stock_api.py:618: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_0 = df_0.append(df_1[cond])
#             종목명      시가      종가     변동폭     등락률        거래량            거래대금
# 티커
# 006840    AK홀딩스   10362   34600   24238  233.91  108421826   5875063291239
# 001460      BYC  125000  236500  111500   89.20    1110900    308886935200
# 001465     BYC우   55000  124000   69000  125.45     729124     98047200600
# 001040       CJ   59124   96600   37476   63.39  279052040  34181522524860
# 079160    CJCGV   22000   34550   12550   57.05  342150609  20065392418899
# ...         ...     ...     ...     ...     ...        ...             ...
# 003450     현대증권   14800       0  -14800 -100.00          0               0
# 114410     현대푸드   15550       0  -15550 -100.00          0               0
# ...
